# %%
require_relative '../modules/aoc'

puzzle = Puzzle.new(2017,11) do | input |
    input
end

puzzle.display(1)  
# puzzle.display(2)
# Out:
# "**Downloading input**"
# "**Downloading puzzle**"
# ...

# %%
def puzzle.part1
    @input
end

def puzzle.part2
    @input
end
puzzle.solve
