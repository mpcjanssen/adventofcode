# %%
(ql:quickload :alexandria)
# Out:
# To load "alexandria":
#   Load 1 ASDF system:
#     alexandria
# (:ALEXANDRIA)
# ; Loading "alexandria"

# %%
(defvar *input* (alexandria:read-file-into-string "input/22.txt"))
*input*
# Out:
# *INPUT*
# ".#...#.#.##..##....##.#.#
# ###.###..##...##.##....##
# ....#.###..#...#####..#.#
# .##.######..###.##..#...#
# #..#..#..##..###...#..###
# ..####...#.##.#.#.##.####
# #......#..####..###..###.
# #####.##.#.#.##.###.#.#.#
# .#.###....###....##....##
# .......########.#.#...#..
# ...###.####.##..###.##..#
# #.#.###.####.###.###.###.
# .######...###.....#......
# ....##.###..#.#.###...##.
# #.###..###.#.#.##.#.##.##
# #.#.#..###...###.###.....
# ##..##.##...##.##..##.#.#
# .....##......##..#.##...#
# ..##.#.###.#...#####.#.##
# ....##..#.#.#.#..###.#..#
# ###..##.##....##.#....##.
# #..####...####.#.##..#.##
# ####.###...####..##.#.#.#
# #.#.#.###.....###.##.###.
# .#...##.#.##..###.#.###..
# "
