# %%
(defpackage :aoc/2015/01 #.cl-user::*aoc-use*)
(in-package :aoc/2015/01)
# Out:
# UNBOUND-VARIABLE: The variable *AOC-USE* is unbound.
# 3: ((FLET "H1" :IN JUPYTER:EVALUATE-CODE) The variable *AOC-USE* is unbound.)
# 4: (SB-KERNEL::%SIGNAL The variable *AOC-USE* is unbound.)
# 5: (ERROR The variable *AOC-USE* is unbound.)
# 6: (SB-KERNEL:WITH-SIMPLE-CONDITION-RESTARTS ERROR NIL The variable *AOC-USE* is unbound.)
# 7: ((LABELS SB-KERNEL::TRY :IN SB-KERNEL::RESTART-UNBOUND) The variable *AOC-USE* is unbound.)
# 8: (SB-KERNEL::RESTART-UNBOUND *AOC-USE* The variable *AOC-USE* is unbound. -134551)
# 9: (SB-KERNEL:INTERNAL-ERROR #.(SB-SYS:INT-SAP #X7F03B9D6DA80) #<unused argument>)
# 10: ("foreign function: call_into_lisp_")
# 11: ("foreign function: funcall2")
# 12: ("foreign function: interrupt_internal_error")
# 13: ("foreign function: #x55C550E77DF1")
# 14: (SB-INT:SIMPLE-EVAL-IN-LEXENV *AOC-USE* #<NULL-LEXENV>)
# 15: (EVAL *AOC-USE*)
# ...
