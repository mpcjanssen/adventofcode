// %%
import * as fs from 'fs';
const input = fs.readFileSync('./input/1.txt','utf8');
const values = {"(" : 1 , ")" : -1}

// %%
input.split("").map((el) => values[el]).reduce((acc, el) => acc + el, 0)
// Out:
// 232

// %%
day01
// Out:
// 1:1 - Cannot find name 'day01'.

// %%
input.split("")
    .map((el) => values[el])
    .reduce((acc, el) => acc.concat(acc[acc.length-1]+el), [0])
    .findIndex((it)=> it == -1)
// Out:
// 1783

// %%
let a = [].push(0)

// %%
a
// Out:
// 1
