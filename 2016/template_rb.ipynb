# %%
require_relative '../modules/aoc'

puzzle = Puzzle.new(2016,x) do | input |
    input
end

puzzle.display(1)  
# puzzle.display(2)

# %%
def puzzle.part1
    @input
end

def puzzle.part2
    @input
end
puzzle.solve
