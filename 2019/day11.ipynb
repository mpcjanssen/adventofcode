# %%
source day11.tcl
# Out:
# couldn't load file "./lib/cintcode/bld/libcintcode.so": ./lib/cintcode/bld/libcintcode.so: cannot open shared object file: No such file or directory
#     while executing
# "load [file join $libdir bld libcintcode.so ]"
#     ("Linux" arm line 1)
#     invoked from within
# "switch -glob $tcl_platform(os) {
#    Windows* {load [file normalize [file join $libdir cmake-build-debug libcintcode.dll]]}
#    Linux {load [file join $..."
#     (file "./lib/cintcode/cintcode-0.1.tm" line 2)
#     invoked from within
# "source -encoding utf-8 ./lib/cintcode/cintcode-0.1.tm"
#     ("package ifneeded cintcode 0.1" script)
#     invoked from within
# "package require cintcode"
#     (file "day11.tcl" line 4)
#     invoked from within
# "source day11.tcl"

# %%
part1
# Out:
# invalid command name "part1"
#     while executing
# "part1"

# %%
part2 1
# Out:
# invalid command name "part2"
#     while executing
# "part2 1"
