# %%
(ql:quickload :uiop)
(defvar *input* (uiop:read-file-lines "./input/1.txt"))
# Out:
# To load "uiop":
#   Load 1 ASDF system:
#     uiop
# (:UIOP)
# *INPUT*
# ; Loading "uiop"

# %%
(defvar *depths* (mapcar #'parse-integer *input*))
# Out:
# *DEPTHS*
