# %%
with open("./input/1.txt") as f:
    ns = list(map(int, (x.strip() for x in f.readlines())))

# %%
sum([ a < b for a,b in zip(ns,ns[1:])])
# Out:
# 1233

# %%
sum([ a < b for a,b in zip(ns,ns[3:])])
# Out:
# 1275
