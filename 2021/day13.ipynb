# %%
source ../modules/setup.tcl

set year 2021
set day 13

aoc::get-puzzle $year $day 1
aoc::get-puzzle $year $day 2
set input [string trim [aoc::get-input $year $day]]
jupyter::display "text/markdown" "## Input\n```\n[string range $input 0 20]...\n```";
# Out:
# (cached)
# <article class="day-desc">
# <h2>--- Day 13: Transparent Origami ---</h2><p>You reach another volcanically active part of the cave. It would be nice if you could do some kind of thermal imaging so you could tell ahead of time which caves are too hot to safely enter.</p>
# <p>Fortunately, the submarine seems to be equipped with a thermal camera! When you activate it, you are greeted with:</p>
# <pre><code>Congratulations on your purchase! To activate this infrared thermal imaging
# camera system, please enter the code found on page 1 of the manual.
# </code></pre>
# <p>Apparently, the Elves have never used this feature. To your surprise, you manage to find the manual; as you go to open it, page 1 falls out. It's a large sheet of <a href="https://en.wikipedia.org/wiki/Transparency_(projection)" target="_blank">transparent paper</a>! The transparent paper is marked with random dots and includes instructions on how to fold it up (your puzzle input). For example:</p>
# ...

# %% [markdown]
# ### Solve today
#
# `aoc::solve input body`:
#     The body is executed as a coroutine. Input is available as the `$input` variable. The results are returned using `[yield]`

# %%
set test {6,10
0,14
9,10
0,3
10,4
4,11
6,0
6,12
4,1
0,13
10,12
3,4
3,0
8,4
1,10
2,14
8,10
9,0

fold along y=7
fold along x=5}



proc foldx {dots linex} {
    set newdots {}
    foreach dot $dots {
        lassign $dot x y
        if {$x <= $linex } {
            lappend newdots $dot
        } else {
            set newx [expr {2*$linex - $x}]
            lappend newdots [list $newx $y]
        }
    }
    return [lsort -unique $newdots]
}

proc display dots {
    set maxx [lindex [lsort -index 0 -decreasing -integer $dots] 0 0]
    set maxy [lindex [lsort -index 1 -decreasing -integer $dots] 0 1]

    for {set y 0} {$y <= $maxy} {incr y} {
        for {set x 0} {$x <= $maxx} {incr x} {
            if {[lsearch $dots [list $x $y]]!= -1} {
                puts -nonewline \u2b1b
            } else {
                puts -nonewline \u2b1c
            }
        }
        puts ""
    }
}

proc foldy {dots liney} {
    set newdots {}
    foreach dot $dots {
#         puts $dot
        lassign $dot x y
        if {$y <= $liney } {
            lappend newdots $dot
        } else {
            set newy [expr {2*$liney - $y}]
#             puts $newy
            lappend newdots [list $x $newy]
        }
    }
    return [lsort -unique $newdots]
}

proc fold {dots _ along linedesc} {
#     puts $linedesc
    lassign [split $linedesc =] axis line
    if {$axis eq "x"} {
        return [foldx $dots $line]
    } else {
        return [foldy $dots $line]
    }
    
}
aoc::solve $input {
lassign [split [string map [list \n\n @] $input] @] first second
# puts $first
# puts $second
set dots {}
foreach dot [split $first \n] {
    lappend dots [split $dot ,]

}
set dots
set firstfold true
foreach fold [split $second \n] {
#     display $dots
    set dots [fold $dots {*}$fold]
    if {$firstfold} {
        yield [llength $dots]
        set firstfold false
    }
    
}
display $dots

}
# Out:
# Part1	842 (2265 us)
# ⬛⬛⬛⬜⬜⬛⬛⬛⬛⬜⬛⬜⬜⬛⬜⬛⬛⬛⬜⬜⬜⬛⬛⬜⬜⬜⬜⬛⬛⬜⬛⬛⬛⬛⬜⬛⬜⬜⬛
# ⬛⬜⬜⬛⬜⬛⬜⬜⬜⬜⬛⬜⬛⬜⬜⬛⬜⬜⬛⬜⬛⬜⬜⬛⬜⬜⬜⬜⬛⬜⬜⬜⬜⬛⬜⬛⬜⬜⬛
# ⬛⬛⬛⬜⬜⬛⬛⬛⬜⬜⬛⬛⬜⬜⬜⬛⬜⬜⬛⬜⬛⬜⬜⬜⬜⬜⬜⬜⬛⬜⬜⬜⬛⬜⬜⬛⬜⬜⬛
# ⬛⬜⬜⬛⬜⬛⬜⬜⬜⬜⬛⬜⬛⬜⬜⬛⬛⬛⬜⬜⬛⬜⬜⬜⬜⬜⬜⬜⬛⬜⬜⬛⬜⬜⬜⬛⬜⬜⬛
# ⬛⬜⬜⬛⬜⬛⬜⬜⬜⬜⬛⬜⬛⬜⬜⬛⬜⬛⬜⬜⬛⬜⬜⬛⬜⬛⬜⬜⬛⬜⬛⬜⬜⬜⬜⬛⬜⬜⬛
# ⬛⬛⬛⬜⬜⬛⬜⬜⬜⬜⬛⬜⬜⬛⬜⬛⬜⬜⬛⬜⬜⬛⬛⬜⬜⬜⬛⬛⬜⬜⬛⬛⬛⬛⬜⬜⬛⬛⬜
# Part2	 (6505 us)
