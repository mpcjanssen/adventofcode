# %%
input = File.open("./input/1.txt").map(&:to_i).freeze
nil

# %%
input.each_cons(2).count  { | a, b | b > a }
# Out:
# 1233

# %%
input.each_cons(3).map(&:sum).each_cons(2).count  { | a, b | b > a }
# Out:
# 1275
